# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv', engine = 'python')
df
# Out:
#         SERIAL_NUM  CUST_LOCATION    AGE  GENDER   JOB BRANCH_DIST  \
# 0           161236              6  55~59       1  10.0   5�����H�W
# 1           163040              6  40~44       1   NaN   5�����H�W
# 2            68474              6  55~59       1   NaN   0.5-1����
# 3           159801              7  25~29       2   NaN   5�����H�W
# 4           117899              5  40~44       2   NaN   5�����H�W
# ...            ...            ...    ...     ...   ...         ...
# 200087      160203              5  45~49       1   6.0   5�����H�W
# 200088       35390              3  50~54       2   6.0   5�����H�W
# 200089      161122              4  45~49       1   NaN   5�����H�W
# 200090      186148              5  30~34       1   4.0   5�����H�W
# 200091      147374              5  40~44       1   2.0   5�����H�W
#
#         AMT_EXCHANGE_A_M1  AMT_EXCHANGE_A_M2  AMT_EXCHANGE_A_M3  \
# 0                       0                  0                  0
# ...

# %%
df.shape
# Out:
# (200092, 331)

# %%
ex = pd.read_excel('feature_detail.xlsx')
ex
# Out:
#     欄位分類            欄位名稱                           附加尾名範圍  欄位數量      欄位說明(初賽)
# 0   基本資料      Serial_num                              NaN   1.0          客戶序號
# 1    NaN   cust_location                              NaN   1.0        客戶所屬地區
# 2    NaN             age                              NaN   1.0          客戶年齡
# 3    NaN          gender                              NaN   1.0          客戶性別
# 4    NaN             job                              NaN   1.0        客戶職業類別
# 5    NaN     Branch_Dist                              NaN   1.0      最近分行距離級距
# 6   產品往來  AMT_Exchange_A                         _M1~_M13  13.0      換匯金額_通路A
# 7    NaN  AMT_Exchange_B                         _M1~_M13  13.0      換匯金額_通路B
# 8    NaN  AMT_Exchange_C                         _M1~_M13  13.0      換匯金額_通路C
# 9    NaN  CNT_Exchange_A                         _M1~_M13  13.0      換匯次數_通路A
# 10   NaN  CNT_Exchange_B                         _M1~_M13  13.0      換匯次數_通路B
# ...
